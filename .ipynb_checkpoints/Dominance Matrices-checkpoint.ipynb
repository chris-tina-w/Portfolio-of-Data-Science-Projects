# %% [markdown]
# # Dominance Matrices

# %% [markdown]
# _I underwent this project for my university mathematics course and interestingly explores the application of dominance matrices to sports teams rankings using R._

# %% [markdown]
# Dominance matrices can provide insight into the rankings of teams who are part of a round-robin styled tournament.
# - It DOESN”T require all teams to have played one another.
# - The rankings are calculated with the number WINS as well as the LOSSES.
# - It can also consider the extent of the wins and losses with ratio scores using RATIO SCORE MATRICES.

# %% [markdown]
# At any round (m), the rankings of the teams can be predicted using a formula:

# %% [markdown]
# ![image.png](attachment:5cea4006-f878-477f-8e6e-aff32c7ee3e1.png)

# %% [markdown]
# r1 is the first order ranking which scores the teams based on their wins and losses so far and is calculated by:

# %% [markdown]
# ![image.png](attachment:1a27e25f-e6d5-4120-a8ab-719ce9135ba5.png)

# %% [markdown]
# r2 is the second order ranking which predicts the outcome of teams who haven’t played one another based on their results from games with a common third team and is calculated by:

# %% [markdown]
# ![image.png](attachment:429ffc7e-0fb3-4dcc-a4e5-b6146b166ab6.png)

# %% [markdown]
# Looking at the 2014 AFL season, I wanted to see if the dominance matrices would give similar rankings compared with the actual AFL footy ladder after 23 rounds.
#
# I used the ratio-scores matrix which gave a score of points won vs points lost for each game played.
#
# For example, after 12 rounds the ratio-scores matrix D(12) looked like this:

# %% [markdown]
# ![image.png](attachment:352d7d5d-e838-4f9c-befe-4b0bbd589216.png)

# %% [markdown]
# After the dominance matrix is compiled, it can be applied to the formula (r = r1 + 0.5*r2). The higher the r, the better the team was considered to be, thus the higher it was ranked in the predicted rankings.

# %% [markdown]
# Here is the method used to solve the formula in R (example looks at round 12):

# %% [markdown]
# ![image.png](attachment:2edff6f3-a74e-4549-99fa-7cdc16a243ca.png)

# %% [markdown]
# ![image.png](attachment:f4b834ee-66a4-48ae-978d-89455a8e795c.png)

# %% [markdown]
# Looking at the predicted rankings vs actual rankings, the dominance matrix rankings placed the teams in the same relative positions as the actual rankings
# - Top 6 teams
# - Middle 5 teams
# - Bottom 7 teams

# %% [markdown]
# ![image.png](attachment:09fab315-fe12-4211-bbe8-e849c8f4cb9b.png)

# %% [markdown]
# The most correctly predicted team rankings was after 18 rounds, with 9 out of 16 positions identified correctly.

# %% [markdown]
# ![image.png](attachment:4c949c8c-751f-473c-be9c-4f95dfbb7b58.png)

# %% [markdown]
# ![image.png](attachment:74d0aa3b-f2a0-49c0-8184-4f78e2da6473.png)

# %% [markdown]
# The dominance matrices accurately determined the relative ranking of teams from early in the season. However, due to differences in actual vs predicted ranking calculations, there was slight variation in the rankings. Overall, the dominance matrix correctly predicted the results of the Final Game, having ranked Hawthorn Hawks above Sydney Swans across all 4 rounds calculated.

# %% [markdown]
# The best formula for prediction through experimenting with different weights for the first and second rankings r1 and r2, and adding in a higher order ranking (r3) was:

# %% [markdown]
# ![image.png](attachment:39b685bf-0fec-440b-a72f-6a17f13cab02.png)

# %% [markdown]
# ![image.png](attachment:0aa9184b-e8f3-4ef9-b88c-a0f6cd29ce0e.png)
